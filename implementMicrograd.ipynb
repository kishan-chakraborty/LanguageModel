# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return 3*x**2 - 4*x +2

# %%
# Plotting the above function
x = np.linspace(-5, 5, 100)
y = f(x)
plt.plot(x, y)

# %%
# The derivative of the abive function
